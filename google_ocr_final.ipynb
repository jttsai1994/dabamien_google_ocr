# %% [markdown]
# <a href="https://colab.research.google.com/github/jttsai1994/dabamien_google_ocr/blob/main/google_ocr_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --upgrade google-cloud-documentai
# Out:
# Collecting google-cloud-documentai
#   Downloading google_cloud_documentai-3.5.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (2.25.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-documentai) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-documentai) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-documentai) (5.29.5)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (2.32.3)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (1.72.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-documentai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-documentai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-documentai) (4.9.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-cloud-documentai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-cloud-documentai) (2025.4.26)
# Downloading google_cloud_documentai-3.5.0-py3-none-any.whl (299 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.1/299.1 kB 7.9 MB/s eta 0:00:00
# Installing collected packages: google-cloud-documentai
# Successfully installed google-cloud-documentai-3.5.0

# %%
pip install --upgrade google-cloud-documentai-toolbox
# Out:
# Collecting google-cloud-documentai-toolbox
#   Downloading google_cloud_documentai_toolbox-0.14.2a0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-documentai-toolbox) (2.25.0)
# Requirement already satisfied: pandas<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (2.2.2)
# Collecting pyarrow<16.0.0,>=15.0.0 (from google-cloud-documentai-toolbox)
#   Downloading pyarrow-15.0.2-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-documentai-toolbox) (0.9.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-cloud-documentai-toolbox) (1.26.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.6 in /usr/local/lib/python3.11/dist-packages (from google-cloud-documentai-toolbox) (0.14.2)
# Requirement already satisfied: google-cloud-bigquery<4.0.0,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-documentai-toolbox) (3.34.0)
# Requirement already satisfied: google-cloud-documentai<4.0.0,>=2.29.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-documentai-toolbox) (3.5.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=1.31.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-documentai-toolbox) (2.19.0)
# Collecting google-cloud-vision<4.0.0,>=2.7.0 (from google-cloud-documentai-toolbox)
#   Downloading google_cloud_vision-3.10.1-py3-none-any.whl.metadata (9.5 kB)
# Collecting numpy<2.0.0,>=1.23.5 (from google-cloud-documentai-toolbox)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.6 MB/s eta 0:00:00
# Collecting intervaltree>=3.0.0 (from google-cloud-documentai-toolbox)
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pikepdf<9.0.0,>=8.0.0 (from google-cloud-documentai-toolbox)
#   Downloading pikepdf-8.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: immutabledict<5.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-documentai-toolbox) (4.2.1)
# Collecting Pillow<11.0.0,>=10.0.0 (from google-cloud-documentai-toolbox)
#   Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: Jinja2<4.0.0,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-documentai-toolbox) (3.1.6)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=2.15.0->google-cloud-documentai-toolbox) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=2.15.0->google-cloud-documentai-toolbox) (5.29.5)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=2.15.0->google-cloud-documentai-toolbox) (2.38.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=2.15.0->google-cloud-documentai-toolbox) (2.32.3)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-bigquery<4.0.0,>=3.5.0->google-cloud-documentai-toolbox) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-bigquery<4.0.0,>=3.5.0->google-cloud-documentai-toolbox) (2.7.2)
# Requirement already satisfied: packaging>=24.2.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-bigquery<4.0.0,>=3.5.0->google-cloud-documentai-toolbox) (24.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-bigquery<4.0.0,>=3.5.0->google-cloud-documentai-toolbox) (2.9.0.post0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage<4.0.0,>=1.31.0->google-cloud-documentai-toolbox) (1.7.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.44.0 in /usr/local/lib/python3.11/dist-packages (from grpc-google-iam-v1<1.0.0,>=0.12.6->google-cloud-documentai-toolbox) (1.72.1)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from intervaltree>=3.0.0->google-cloud-documentai-toolbox) (2.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2<4.0.0,>=3.1.0->google-cloud-documentai-toolbox) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.0.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.0.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (2025.2)
# Requirement already satisfied: bottleneck>=1.3.6 in /usr/local/lib/python3.11/dist-packages (from pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (1.4.2)
# Requirement already satisfied: numba>=0.56.4 in /usr/local/lib/python3.11/dist-packages (from pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (0.60.0)
# Requirement already satisfied: numexpr>=2.8.4 in /usr/local/lib/python3.11/dist-packages (from pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (2.10.2)
# Requirement already satisfied: gcsfs>=2022.11.0 in /usr/local/lib/python3.11/dist-packages (from pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (2025.3.2)
# Requirement already satisfied: pandas-gbq>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (0.29.0)
# Collecting Deprecated (from pikepdf<9.0.0,>=8.0.0->google-cloud-documentai-toolbox)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: lxml>=4.8 in /usr/local/lib/python3.11/dist-packages (from pikepdf<9.0.0,>=8.0.0->google-cloud-documentai-toolbox) (5.4.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from gcsfs>=2022.11.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (3.11.15)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.11/dist-packages (from gcsfs>=2022.11.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (4.4.2)
# Requirement already satisfied: fsspec==2025.3.2 in /usr/local/lib/python3.11/dist-packages (from gcsfs>=2022.11.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (2025.3.2)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.11/dist-packages (from gcsfs>=2022.11.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (1.2.2)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]<3.0.0,>=2.11.1->google-cloud-bigquery<4.0.0,>=3.5.0->google-cloud-documentai-toolbox) (1.71.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=2.15.0->google-cloud-documentai-toolbox) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=2.15.0->google-cloud-documentai-toolbox) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=2.15.0->google-cloud-documentai-toolbox) (4.9.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.56.4->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (0.43.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from pandas-gbq>=0.19.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (75.2.0)
# Requirement already satisfied: db-dtypes<2.0.0,>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from pandas-gbq>=0.19.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (1.4.3)
# Requirement already satisfied: pydata-google-auth>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from pandas-gbq>=0.19.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (1.9.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery<4.0.0,>=3.5.0->google-cloud-documentai-toolbox) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->google-cloud-documentai-toolbox) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->google-cloud-documentai-toolbox) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->google-cloud-documentai-toolbox) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core<3.0.0,>=2.15.0->google-cloud-documentai-toolbox) (2025.4.26)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->pikepdf<9.0.0,>=8.0.0->google-cloud-documentai-toolbox) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2022.11.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (1.20.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib->gcsfs>=2022.11.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=2.15.0->google-cloud-documentai-toolbox) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs>=2022.11.0->pandas[gcp,performance]<3.0.0,>=2.0.0->google-cloud-documentai-toolbox) (3.2.2)
# Downloading google_cloud_documentai_toolbox-0.14.2a0-py2.py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 kB 1.6 MB/s eta 0:00:00
# Downloading google_cloud_vision-3.10.1-py3-none-any.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.1/526.1 kB 18.0 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 55.3 MB/s eta 0:00:00
# Downloading pikepdf-8.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 46.5 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 37.4 MB/s eta 0:00:00
# Downloading pyarrow-15.0.2-cp311-cp311-manylinux_2_28_x86_64.whl (38.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.3/38.3 MB 12.1 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: intervaltree
#   Building wheel for intervaltree (setup.py) ... done
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26098 sha256=da5f1940a3156d5d2801ea9f2cc8e59af2e9b394ab283eb3536c471ec645a657
#   Stored in directory: /root/.cache/pip/wheels/31/d7/d9/eec6891f78cac19a693bd40ecb8365d2f4613318c145ec9816
# Successfully built intervaltree
# Installing collected packages: Pillow, numpy, intervaltree, Deprecated, pyarrow, pikepdf, google-cloud-vision, google-cloud-documentai-toolbox
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.2.1
#     Uninstalling pillow-11.2.1:
#       Successfully uninstalled pillow-11.2.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed Deprecated-1.2.18 Pillow-10.4.0 google-cloud-documentai-toolbox-0.14.2a0 google-cloud-vision-3.10.1 intervaltree-3.1.0 numpy-1.26.4 pikepdf-8.15.1 pyarrow-15.0.2

# %%
pip install --upgrade google-cloud-storage
# Out:
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.11/dist-packages (2.19.0)
# Collecting google-cloud-storage
#   Downloading google_cloud_storage-3.1.0-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (2.38.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (2.25.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (2.7.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (2.32.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2025.4.26)
# ^C

# %%
import os

# 設置環境變數，指向服務帳戶密鑰檔案
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "dabamien-2228a0999974.json"

# %%
from google.api_core.client_options import ClientOptions
from google.cloud import documentai


PROJECT_ID = "dabamien"
LOCATION = "us"  # Format is 'us' or 'eu'
PROCESSOR_ID = "ef432a9e6acb161f"  # Create processor in Cloud Console

# The local file in your current working directory
FILE_PATH = "測試用連署書_手寫.pdf"
# Refer to https://cloud.google.com/document-ai/docs/file-types
# for supported file types
MIME_TYPE = "application/pdf"

# Instantiates a client
docai_client = documentai.DocumentProcessorServiceClient(
    client_options=ClientOptions(api_endpoint=f"{LOCATION}-documentai.googleapis.com")
)

# The full resource name of the processor, e.g.:
# projects/project-id/locations/location/processor/processor-id
# You must create new processors in the Cloud Console first
RESOURCE_NAME = docai_client.processor_path(PROJECT_ID, LOCATION, PROCESSOR_ID)

# Read the file into memory
with open(FILE_PATH, "rb") as image:
    image_content = image.read()

# Load Binary Data into Document AI RawDocument Object
raw_document = documentai.RawDocument(content=image_content, mime_type=MIME_TYPE)

# Configure the process request
request = documentai.ProcessRequest(name=RESOURCE_NAME, raw_document=raw_document)

# Use the Document AI client to process the sample form
result = docai_client.process_document(request=request)

document_object = result.document
print("Document processing complete.")
# print(f"Text: {document_object.text}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d851bdf4ce73> in <cell line: 0>()
#      24
#      25 # Read the file into memory
# ---> 26 with open(FILE_PATH, "rb") as image:
#      27     image_content = image.read()
#      28
#
# FileNotFoundError: [Errno 2] No such file or directory: '測試用連署書_手寫.pdf'

# %%
# for page in document_object.pages:
#     for paragraph in page.paragraphs:
#       start_index = paragraph.layout.text_anchor.text_segments[0].start_index
#       end_index = paragraph.layout.text_anchor.text_segments[0].end_index
#       paragraph_text = document_object.text[start_index:end_index]
#       print(f"段落: {paragraph_text}")
#     print("==========")

# %% [markdown]
#  ## 一頁單筆資料可用

# %%
# import re
# import pandas as pd
# from datetime import datetime
# def parse_document(document_object):
#     # 初始化結果列表
#     results = []

#     # 遍歷每一頁
#     for page in document_object.pages:
#         page_data = {
#             "地址": None,
#             "里": None,
#             "鄰": None,
#             "路/街": None,
#             "出生年月日": None,
#             "年齡": None,
#             "身分證字號": None,
#             "性別": None
#         }

#         # 遍歷每一段落
#         for paragraph in page.paragraphs:
#             start_index = paragraph.layout.text_anchor.text_segments[0].start_index
#             end_index = paragraph.layout.text_anchor.text_segments[0].end_index
#             paragraph_text = document_object.text[start_index:end_index].strip()
#             print(paragraph_text)
#             print("================")
#             # 提取地址
#             if "里" in paragraph_text and "鄰" in paragraph_text:
#                 page_data["地址"] = paragraph_text
#                 # 提取里、鄰、路/街
#                 page_data["里"] = extract_specific_field(paragraph_text, r"([一-龥]{1,2})里")
#                 page_data["鄰"] = extract_specific_field(paragraph_text, r"(\d{1,2})鄰")
#                 page_data["路/街"] = extract_specific_field(paragraph_text, r"([一-龥]{1,3})(路|街)(?!鄰)")

#             # 提取出生年月日
#             birth_date = extract_birth_date(paragraph_text)
#             if birth_date:
#                 page_data["出生年月日"] = birth_date
#                 # 計算年齡
#                 page_data["年齡"] = calculate_age(birth_date)

#             # 提取身分證字號（寬鬆匹配）
#             if re.search(r"[A-Z][0-9]+", paragraph_text):  # 匹配英文字母開頭，後接數字
#                 page_data["身分證字號"] = paragraph_text
#                 # 判斷性別
#                 page_data["性別"] = determine_gender(paragraph_text)

#         # 如果該頁有完整的數據，加入結果列表
#         print("=====next page=======")
#         if page_data["地址"] or page_data["出生年月日"] or page_data["身分證字號"]:
#             results.append(page_data)

#     return results


# def extract_specific_field(text, pattern):
#     """提取地址中的特定字段（如里、鄰、路/街），並排除鄰字干擾"""
#     match = re.search(pattern, text)
#     if match:
#         # 移除匹配結果中的「鄰」字
#         result = match.group(0)
#         return result.replace("鄰", "")  # 確保「鄰」字被移除
#     return None

# def extract_birth_date(text):
#     """提取生日，支持多種格式並修正錯誤年份"""
#     # 匹配日期格式 (民國或簡寫)
#     match = re.search(r"(\d{2,3}\.\d{1,2}\.\d{1,2})|民國(\d{2,3})年(\d{1,2})月(\d{1,2})日|(\d{2,3})年(\d{1,2})月(\d{1,2})日", text)
#     if match:
#         if match.group(1):  # 簡寫格式 (如 65.11.28 或 646.07.02)
#             year, month, day = match.group(1).split(".")
#             year = correct_year(year)  # 修正年份
#             return f"{year}.{month}.{day}"
#         elif match.group(2):  # 民國完整格式 (如 民國65年11月28日)
#             year = correct_year(match.group(2))  # 修正年份
#             month = match.group(3)
#             day = match.group(4)
#             return f"{year}.{month}.{day}"
#         elif match.group(5):  # 未標註民國的格式 (如 65年11月28日)
#             year = correct_year(match.group(5))  # 修正年份
#             month = match.group(6)
#             day = match.group(7)
#             return f"{year}.{month}.{day}"
#     return None

# def correct_year(year):
#     """修正年份，確保符合規則"""
#     year = int(year)
#     if len(str(year)) == 3 and str(year)[0] != "1":
#         # 如果是三位數且不是以1開頭，取後兩位數
#         year = int(str(year)[-2:])
#     return year

# def calculate_age(birth_date):
#     """根據出生年月日計算年齡"""
#     try:
#         # 將日期轉換為西元格式
#         if re.match(r"^\d{2,3}\.\d{1,2}\.\d{1,2}$", birth_date):
#             year, month, day = map(int, birth_date.split("."))
#             year += 1911  # 民國轉西元
#         else:
#             return None

#         # 計算年齡
#         birth_date = datetime(year, month, day)
#         today = datetime.today()
#         age = today.year - birth_date.year - ((today.month, today.day) < (birth_date.month, birth_date.day))
#         return age
#     except Exception as e:
#         print(f"無法計算年齡: {e}")
#         return None

# def determine_gender(id_number):
#     """根據身分證字號判斷性別"""
#     try:
#         # 提取第二碼（數字）
#         match = re.search(r"[A-Z]([0-9])", id_number)
#         if match:
#             gender_digit = int(match.group(1))
#             return "男性" if gender_digit == 1 else "女性"
#         else:
#             return None
#     except Exception as e:
#         print(f"無法判斷性別: {e}")
#         return None

# %%
# parsed_results = parse_document(document_object)

# # 將結果轉換為表格格式
# df = pd.DataFrame(parsed_results)
# print(df)

# %%
df
# Out:
#                              地址    里     鄰   路/街    出生年月日  年齡       身分證字號  性別
# 0       新北市新店區中山里1鄰\n央北一路126號七樓  中山里     1  央北一路  60.4.19  54  L220623341  女性
# 1   新北市新店區信義里14鄰中興路三段\n229號二十三樓  信義里    14   中興路  40.5.27  74  A127494749  男性
# 2                   新北市新店區張北里二鄰  張北里  None  None  79.10.9  34  F121195153  男性
# 3  57年1月13日 新北市新店區柴埕里6鄰安民街68號七樓  柴埕里     6   安民街  57.1.13  57  F103935015  男性

# %% [markdown]
# ## 一頁多筆測試

# %%
# def parse_document_mul(document_object):
#     # 初始化結果列表
#     results = []
#     current_data = None  # 用於存儲當前正在處理的資料
#     last_name = None  # 用於存儲最近檢測到的姓名

#     # 遍歷每一頁
#     for page in document_object.pages:
#         for paragraph in page.paragraphs:
#             start_index = paragraph.layout.text_anchor.text_segments[0].start_index
#             end_index = paragraph.layout.text_anchor.text_segments[0].end_index
#             paragraph_text = document_object.text[start_index:end_index].strip()
#             print(paragraph_text)
#             print("================")

#             # 檢測是否是姓名（假設姓名是兩到三個中文字）
#             if re.match(r"^[\u4e00-\u9fa5]{2,3}$", paragraph_text):  # 中文姓名
#                 last_name = paragraph_text

#             # 檢測是否是新資料的起始點（例如身分證字號）
#             if re.search(r"[A-Z][0-9]+", paragraph_text):  # 身分證字號
#                 # 如果有正在累積的資料，先保存到結果列表
#                 if current_data:
#                     results.append(current_data)
#                 # 開始新的資料分組
#                 current_data = {
#                     "姓名": last_name,  # 使用最近檢測到的姓名
#                     "地址": None,
#                     "里": None,
#                     "鄰": None,
#                     "路/街": None,
#                     "出生年月日": None,
#                     "年齡": None,
#                     "身分證字號": None,
#                     "性別": None
#                 }
#                 current_data["身分證字號"] = paragraph_text
#                 current_data["性別"] = determine_gender(paragraph_text)

#             elif "里" in paragraph_text and "鄰" in paragraph_text:  # 地址相關
#                 if current_data:
#                     current_data["地址"] = paragraph_text
#                     current_data["里"] = extract_specific_field(paragraph_text, r"([一-龥]{1,2})里")
#                     current_data["鄰"] = extract_specific_field(paragraph_text, r"(\d{1,2})鄰")
#                     current_data["路/街"] = extract_specific_field(paragraph_text, r"([一-龥]{1,3})(路|街)(?!鄰)")

#             elif extract_birth_date(paragraph_text):  # 出生年月日
#                 if current_data:
#                     birth_date = extract_birth_date(paragraph_text)
#                     current_data["出生年月日"] = birth_date
#                     current_data["年齡"] = calculate_age(birth_date)

#         # 如果有未保存的資料，保存到結果列表
#         if current_data:
#             results.append(current_data)
#             current_data = None  # 重置分組

#     return results

# %%
# parsed_results_mul = parse_document_mul(document_object)

# # 將結果轉換為表格格式
# df_mul = pd.DataFrame(parsed_results_mul)
# print(df_mul)

# %%
import re
import pandas as pd
from datetime import datetime
from openpyxl import Workbook

def parse_document(document_object):
    # 初始化結果列表
    addresses = []
    birth_dates = []
    id_numbers = []

    # 遍歷每一頁
    for page_number, page in enumerate(document_object.pages, start=1):
        # 遍歷每一段落
        for paragraph in page.paragraphs:
            start_index = paragraph.layout.text_anchor.text_segments[0].start_index
            end_index = paragraph.layout.text_anchor.text_segments[0].end_index
            paragraph_text = document_object.text[start_index:end_index].strip()
            print(paragraph_text)
            print("================")

            # 初始化當前段落的資料
            current_data = {
                "地址": None,
                "里": None,
                "鄰": None,
                "路/街": None,
                "出生年月日": None,
                "年齡": None,
                "身分證字號": None,
                "性別": None,
                "頁碼": page_number
            }

            # 提取地址
            if "里" in paragraph_text and "鄰" in paragraph_text:
                current_data["地址"] = paragraph_text
                current_data["里"] = extract_specific_field(paragraph_text, r"([一-龥]{1,2})里")
                current_data["鄰"] = extract_specific_field(paragraph_text, r"(\d{1,2})鄰")
                current_data["路/街"] = extract_specific_field(paragraph_text, r"([一-龥]{1,3})(路|街)(?!鄰)")

            # 提取出生年月日
            birth_date = extract_birth_date(paragraph_text)
            if birth_date:
                current_data["出生年月日"] = birth_date
                current_data["年齡"] = calculate_age(birth_date)

            # 提取身分證字號
            if re.search(r"[A-Z][0-9]+", paragraph_text):
                current_data["身分證字號"] = paragraph_text
                current_data["性別"] = determine_gender(paragraph_text)

            # 如果該段落有地址，存入地址列表
            if current_data["地址"]:
                addresses.append({
                    "地址": current_data["地址"],
                    "里": current_data["里"],
                    "鄰": current_data["鄰"],
                    "路/街": current_data["路/街"],
                    "頁碼": current_data["頁碼"]
                })

            # 如果該段落有出生年月日，存入出生年月日列表
            if current_data["出生年月日"]:
                birth_dates.append({
                    "出生年月日": current_data["出生年月日"],
                    "年齡": current_data["年齡"],
                    "頁碼": current_data["頁碼"]
                })

            # 如果該段落有身分證字號，存入身分證字號列表
            if current_data["身分證字號"]:
                id_numbers.append({
                    "身分證字號": current_data["身分證字號"],
                    "性別": current_data["性別"],
                    "頁碼": current_data["頁碼"]
                })

    return addresses, birth_dates, id_numbers


def extract_names(document_object, file_name):
    """提取名字並記錄所在檔案和頁碼"""
    names = []  # 用於存儲名字及其位置

    # 遍歷每一頁
    for page_number, page in enumerate(document_object.pages, start=1):
        for paragraph in page.paragraphs:
            start_index = paragraph.layout.text_anchor.text_segments[0].start_index
            end_index = paragraph.layout.text_anchor.text_segments[0].end_index
            paragraph_text = document_object.text[start_index:end_index].strip()

            # 檢測是否是名字（假設名字是兩到三個中文字）
            if re.match(r"^[\u4e00-\u9fa5]{2,3}$", paragraph_text):  # 中文姓名
                names.append({
                    "檔案名稱": file_name,
                    "頁碼": page_number,
                    "姓名": paragraph_text
                })

    return names


def extract_specific_field(text, pattern):
    """提取地址中的特定字段（如里、鄰、路/街）"""
    match = re.search(pattern, text)
    if match:
        result = match.group(0)
        return result.replace("鄰", "")  # 確保「鄰」字被移除
    return None

def extract_birth_date(text):
    """提取生日，支持多種格式並修正錯誤年份"""
    match = re.search(r"(\d{2,3}\.\d{1,2}\.\d{1,2})|民國(\d{2,3})年(\d{1,2})月(\d{1,2})日|(\d{2,3})年(\d{1,2})月(\d{1,2})日", text)
    if match:
        if match.group(1):  # 簡寫格式
            year, month, day = match.group(1).split(".")
            year = correct_year(year)
            return f"{year}.{month}.{day}"
        elif match.group(2):  # 民國完整格式
            year = correct_year(match.group(2))
            month = match.group(3)
            day = match.group(4)
            return f"{year}.{month}.{day}"
        elif match.group(5):  # 未標註民國的格式
            year = correct_year(match.group(5))
            month = match.group(6)
            day = match.group(7)
            return f"{year}.{month}.{day}"
    return None

def correct_year(year):
    """修正年份，確保符合規則"""
    year = int(year)
    if len(str(year)) == 3 and str(year)[0] != "1":
        year = int(str(year)[-2:])
    return year

def calculate_age(birth_date):
    """根據出生年月日計算年齡"""
    try:
        if re.match(r"^\d{2,3}\.\d{1,2}\.\d{1,2}$", birth_date):
            year, month, day = map(int, birth_date.split("."))
            year += 1911  # 民國轉西元
        else:
            return None

        birth_date = datetime(year, month, day)
        today = datetime.today()
        age = today.year - birth_date.year - ((today.month, today.day) < (birth_date.month, birth_date.day))
        return age
    except Exception as e:
        print(f"無法計算年齡: {e}")
        return None

def determine_gender(id_number):
    """根據身分證字號判斷性別"""
    try:
        match = re.search(r"[A-Z]([0-9])", id_number)
        if match:
            gender_digit = int(match.group(1))
            return "男性" if gender_digit == 1 else "女性"
        else:
            return None
    except Exception as e:
        print(f"無法判斷性別: {e}")
        return None

# 主程式
def main(document_object, FILE_PATH):
    file_name = FILE_PATH.split("/")[-1]  # 提取檔案名稱
    # 提取地址、出生年月日、身分證字號
    addresses, birth_dates, id_numbers = parse_document(document_object)

    # 提取名字
    names = extract_names(document_object, file_name)

    # 將結果存入 DataFrame
    df_addresses = pd.DataFrame(addresses)
    df_birth_dates = pd.DataFrame(birth_dates)
    df_id_numbers = pd.DataFrame(id_numbers)
    df_names = pd.DataFrame(names)

    # 將 DataFrame 存入 Excel 的不同分頁
    output_excel_path = "parsed_results.xlsx"
    with pd.ExcelWriter(output_excel_path, engine="openpyxl") as writer:
        df_addresses.to_excel(writer, sheet_name="地址", index=False)
        df_birth_dates.to_excel(writer, sheet_name="出生年月日", index=False)
        df_id_numbers.to_excel(writer, sheet_name="身分證字號", index=False)
        df_names.to_excel(writer, sheet_name="名字", index=False)

    print(f"結果已存入 {output_excel_path}")

# 假設 document_object 是 Document AI 的解析結果
# main(document_object, "example_file.pdf")

# %% [markdown]
# ## dataframe 只取得名字與其所在檔案的頁數

# %%
import re
import pandas as pd

def extract_names(document_object, file_name):
    """提取名字並記錄所在檔案和頁碼"""
    names = []  # 用於存儲名字及其位置

    # 遍歷每一頁
    for page_number, page in enumerate(document_object.pages, start=1):
        for paragraph in page.paragraphs:
            start_index = paragraph.layout.text_anchor.text_segments[0].start_index
            end_index = paragraph.layout.text_anchor.text_segments[0].end_index
            paragraph_text = document_object.text[start_index:end_index].strip()

            # 檢測是否是名字（假設名字是兩到三個中文字）
            if re.match(r"^[\u4e00-\u9fa5]{2,3}$", paragraph_text):  # 中文姓名
                names.append({
                    "檔案名稱": file_name,
                    "頁碼": page_number,
                    "姓名": paragraph_text
                })

    return names


# 使用範例
# 假設 `documents` 是 Document AI 解析的 Document 物件列表
# 假設 `file_names` 是對應的檔案名稱列表
# df = extract_names_from_documents(documents, file_names)

# 將結果存成 CSV
# df.to_csv("names_with_file_and_page.csv", index=False, encoding="utf-8-sig")
# print(df)

# %%
# 提取名字
file_name = FILE_PATH.split("/")[-1]  # 提取檔案名稱
names = extract_names(document_object, file_name)

# 輸出結果
import pandas as pd
df_names = pd.DataFrame(names)
# output_csv_path = "names_extracted.csv"
# df.to_csv(output_csv_path, index=False, encoding="utf-8-sig")
# print(f"名字提取完成，結果已存入 {output_csv_path}")

# %%
df_names
# Out:
#              檔案名稱  頁碼   姓名
# 0   測試用連署書_手寫.pdf   1   編姓
# 1   測試用連署書_手寫.pdf   1  新北市
# 2   測試用連署書_手寫.pdf   1  祭欣妤
# 3   測試用連署書_手寫.pdf   1  吳淑芬
# 4   測試用連署書_手寫.pdf   1   王雲
# 5   測試用連署書_手寫.pdf   1   樓之
# 6   測試用連署書_手寫.pdf   1  模欣好
# 7   測試用連署書_手寫.pdf   1  吳淑芳
# 8   測試用連署書_手寫.pdf   2   編姓
# 9   測試用連署書_手寫.pdf   2  新北市
# 10  測試用連署書_手寫.pdf   2  江次郎
# 11  測試用連署書_手寫.pdf   2  江次郎
# 12  測試用連署書_手寫.pdf   2  陳冠銘
# 13  測試用連署書_手寫.pdf   2   鹽湯
# 14  測試用連署書_手寫.pdf   3   編姓
# 15  測試用連署書_手寫.pdf   3  新北市
# 16  測試用連署書_手寫.pdf   3   樓之
# 17  測試用連署書_手寫.pdf   3  張秋香
# 18  測試用連署書_手寫.pdf   3   黄茹
# 19  測試用連署書_手寫.pdf   3  黃菇紫
# 20  測試用連署書_手寫.pdf   3  胡文忠
# 21  測試用連署書_手寫.pdf   3  高美鈴
# 22  測試用連署書_手寫.pdf   3  高美鈴
# 23  測試用連署書_手寫.pdf   4   編姓
# 24  測試用連署書_手寫.pdf   4  新北市
# 25  測試用連署書_手寫.pdf   4   樓之
# 26  測試用連署書_手寫.pdf   4  何沐恬
# 27  測試用連署書_手寫.pdf   4   脂肪
# 28  測試用連署書_手寫.pdf   4  何景瑄
# 29  測試用連署書_手寫.pdf   4  游世来
# 30  測試用連署書_手寫.pdf   4  游如果

# %% [markdown]
# ## Batch Processing Request to Document AI

# %%
"""
Makes a Batch Processing Request to Document AI
"""

import re

from google.api_core.client_options import ClientOptions
from google.api_core.exceptions import InternalServerError
from google.api_core.exceptions import RetryError
from google.cloud import documentai
from google.cloud import storage

# TODO(developer): Fill these variables before running the sample.

project_id = "dabamien"
location = "us"  # Format is "us" or "eu"
processor_id = "ef432a9e6acb161f"  # Create processor before running sample
gcs_output_uri = "gs://bamien/results"  # Must end with a trailing slash `/`. Format: gs://bucket/directory/subdirectory/
# processor_version_id = (
#     "YOUR_PROCESSOR_VERSION_ID"  # Optional. Example: pretrained-ocr-v1.0-2020-09-23
# )

# TODO(developer): If `gcs_input_uri` is a single file, `mime_type` must be specified.
gcs_input_uri = "gs://bamien/hsindian"  # Format: `gs://bucket/directory/file.pdf` or `gs://bucket/directory/`
input_mime_type = "application/pdf"
field_mask = "text,entities,pages.pageNumber"  # Optional. The fields to return in the Document object.


def batch_process_documents(
    project_id: str,
    location: str,
    processor_id: str,
    gcs_input_uri: str,
    gcs_output_uri: str,
    processor_version_id: str = None,
    input_mime_type: str = None,
    field_mask: str = None,
    timeout: int = 400,
):
    # You must set the api_endpoint if you use a location other than "us".
    opts = ClientOptions(api_endpoint=f"{location}-documentai.googleapis.com")

    client = documentai.DocumentProcessorServiceClient(client_options=opts)

    if not gcs_input_uri.endswith("/") and "." in gcs_input_uri:
        # Specify specific GCS URIs to process individual documents
        gcs_document = documentai.GcsDocument(
            gcs_uri=gcs_input_uri, mime_type=input_mime_type
        )
        # Load GCS Input URI into a List of document files
        gcs_documents = documentai.GcsDocuments(documents=[gcs_document])
        input_config = documentai.BatchDocumentsInputConfig(gcs_documents=gcs_documents)
    else:
        # Specify a GCS URI Prefix to process an entire directory
        gcs_prefix = documentai.GcsPrefix(gcs_uri_prefix=gcs_input_uri)
        input_config = documentai.BatchDocumentsInputConfig(gcs_prefix=gcs_prefix)

    # Cloud Storage URI for the Output Directory
    gcs_output_config = documentai.DocumentOutputConfig.GcsOutputConfig(
        gcs_uri=gcs_output_uri, field_mask=field_mask
    )

    # Where to write results
    output_config = documentai.DocumentOutputConfig(gcs_output_config=gcs_output_config)

    if processor_version_id:
        # The full resource name of the processor version, e.g.:
        # projects/{project_id}/locations/{location}/processors/{processor_id}/processorVersions/{processor_version_id}
        name = client.processor_version_path(
            project_id, location, processor_id, processor_version_id
        )
    else:
        # The full resource name of the processor, e.g.:
        # projects/{project_id}/locations/{location}/processors/{processor_id}
        name = client.processor_path(project_id, location, processor_id)

    request = documentai.BatchProcessRequest(
        name=name,
        input_documents=input_config,
        document_output_config=output_config,
    )

    # BatchProcess returns a Long Running Operation (LRO)
    operation = client.batch_process_documents(request)

    # Continually polls the operation until it is complete.
    # This could take some time for larger files
    # Format: projects/{project_id}/locations/{location}/operations/{operation_id}
    try:
        print(f"Waiting for operation {operation.operation.name} to complete...")
        operation.result(timeout=timeout)
    # Catch exception when operation doesn"t finish before timeout
    except (RetryError, InternalServerError) as e:
        print(e.message)

    # NOTE: Can also use callbacks for asynchronous processing
    #
    # def my_callback(future):
    #   result = future.result()
    #
    # operation.add_done_callback(my_callback)

    # Once the operation is complete,
    # get output document information from operation metadata
    metadata = documentai.BatchProcessMetadata(operation.metadata)

    if metadata.state != documentai.BatchProcessMetadata.State.SUCCEEDED:
        raise ValueError(f"Batch Process Failed: {metadata.state_message}")

    storage_client = storage.Client()

    print("Output files:")
    # One process per Input Document
    for process in list(metadata.individual_process_statuses):
        # output_gcs_destination format: gs://BUCKET/PREFIX/OPERATION_NUMBER/INPUT_FILE_NUMBER/
        # The Cloud Storage API requires the bucket name and URI prefix separately
        matches = re.match(r"gs://(.*?)/(.*)", process.output_gcs_destination)
        if not matches:
            print(
                "Could not parse output GCS destination:",
                process.output_gcs_destination,
            )
            continue

        output_bucket, output_prefix = matches.groups()

        # Get List of Document Objects from the Output Bucket
        output_blobs = storage_client.list_blobs(output_bucket, prefix=output_prefix)

        # Document AI may output multiple JSON files per source file
        for blob in output_blobs:
            # Document AI should only output JSON files to GCS
            if blob.content_type != "application/json":
                print(
                    f"Skipping non-supported file: {blob.name} - Mimetype: {blob.content_type}"
                )
                continue

            # Download JSON File as bytes object and convert to Document Object
            print(f"Fetching {blob.name}")
            document = documentai.Document.from_json(
                blob.download_as_bytes(), ignore_unknown_fields=True
            )

            # For a full list of Document object attributes, please reference this page:
            # https://cloud.google.com/python/docs/reference/documentai/latest/google.cloud.documentai_v1.types.Document

            # Read the text recognition output from the processor
            print("The document contains the following text:")
            print(document.text)


if __name__ == "__main__":
    batch_process_documents(
        project_id=project_id,
        location=location,
        processor_id=processor_id,
        gcs_input_uri=gcs_input_uri,
        gcs_output_uri=gcs_output_uri,
        input_mime_type=input_mime_type,
        field_mask=field_mask,
    )
# Out:
# Waiting for operation projects/579434185475/locations/us/operations/15560794818710564337 to complete...
# Output files:
# Fetching results/15560794818710564337/0/測試用連署書-0.json
# The document contains the following text:
# 編 姓
# 號
# 18
# 姓「國統
# 新北市第11 選舉區立法委員羅明才罷免案連署人名冊
# 民 身
# 分
# 編
# 名 證號
# 里 弄
# 地
# 戶
# 籍
# 出生年月日
# 新北市
# 號
# 新北市新店區張北里19鄰
# 段
# 路(街)
# 樓之
# 129583646.07.02 德五街27巷29弄139號一樓
# 址
# 簽名或蓋章 備註
# 新北市第11 選舉區立法委員羅明才罷免案連署人名冊
# 編
# 號 統
# 姓國 統
# 名
# 戸
# 籍
# 地
# 址
# 民 身
# 分 證
# 編
# 號
# 出生年月日
# 新北市
# 段
# 區
# 巷
# 里
# 鄰
# 路(街)
# 簽名或蓋章 備註
# 弄
# 號。 樓之
# 228
# 民國82年1月17日
# 新北市新店區張北里5鄰中興路
# N225.1089
# 二段53號十八樓
# 新北市第11 選舉區立法委員羅明才罷免案連署人名冊
# 編 姓
# 名
# 戶
# 地
# 址
# 國
# 民
# 身
# 分
# 證
# 出生年月日
# 新北市
# 里
# 鄰
# 號 統
# 編
# 號
# 段
# 巷
# 弄
# 號
# 路(街)
# 樓之
# 簽名或蓋章 備
# 註
# 144
# 90年2月22日
# 新北市新店區中正里7鄰華中街38號一樓
# F130 600 6
# 新北市第11 選舉區立法委員羅明才罷免案連署人名冊
# 編 姓
# 名
# 戶
# 籍
# 地
# 址
# 號
# 國統
# 民 身
# 證 出生年月日
# 新北市
# 里
# 路(街)
# 簽名或蓋章 備註
# 編
# 號
# 段
# 巷
# 弄
# 號
# 樓之
# 242
# A12539119
# 65.11.28 啟文路78号三樓
# 新北市新店區中山里1鄰
# 新北市第11選舉區立法委員羅明才罷免案連署人名冊
# 編
# 號 統
# 姓國 統
# 民
# 編
# 名
# 戶
# 籍
# 地
# 址
# 證號
# 出生年月日
# 新北市
# 品
# 里
# 路(街)
# 簽名或蓋章| 備註
# 段
# 巷
# 弄
# 號
# 樓之
# 號
# 60.8.19
# 新北市新店區信義里14鄰
# 中興路三段ユニク號+一樓
# A:209197
# 新北市第11 選舉區立法委員羅明才罷免案連署人名冊
# 編 姓
# 國統
# 民
# 名
# 籍
# 地
# 址
# 身
# 證 出生年月日
# 新北市
# 編
# 號
# 段
# 巷
# 里弄
# 路(街) 簽名或蓋章「備註
# 號
# 樓之
# 新北市新店區柴堆里2鄰埕路
# 267
# 44.2.7
# F20 857.63
# 36巷16號
# 新北市第 11 選舉區立法委員羅明才罷免案連署人名冊
# 編姓
# 名
# 戶
# 籍
# 地
# 沚
# 號 統
# 國統
# 民 身
# 分
# 編
# 證
# 出生年月日
# 新北市
# 品
# 里
# 鄰
# 段
# 巷
# 弄
# 號
# 路(街)
# 樓之
# 簽名或蓋章 備
# 註
# 80
# F1035681
# 42.3.23
# 新北市新店區公崙里9鄰安東路二段34號
# 新北市第 11 選舉區立法委員羅明才罷免案連署人名冊
# 編 姓
# 名
# 戶
# 地
# 址
# 民 身
# 證 出生年月日
# 新北市
# 區
# 號 統
# 編
# 段
# 巷
# 里
# 弄
# 鄰
# 路(街)
# 簽名或蓋章 備註
# 號
# 樓之
# 238
# A221 20 18
# 54.10.25
# 新北市新店區香坡里1鄰
# 安祥路109巷3弄5號
# 新北市第11選舉區立法委員羅明才罷免案連署人名冊
# 編 姓
# 號
# 國統
# 名
# 籍
# 地
# 址
# -
# 民 身分 證 出生年月日
# 編
# 號
# 新北市
# 段
# 巷
# 里 弄
# 鄰
# 號
# 路(街)
# 樓之
# 簽名或蓋章 備註
# 王大明
# A120123456
# 76.4.28 新北市新店區香坡里4鄰
# 安祥路xx號
# 新北市第11選舉區立法委員羅明才罷免案連署人名冊
# 姓「國 統
# 編
# 編
# 號
# 名
# 籍
# 地
# 址
# 民 身
# 分 證 出生年月日
# 編
# 號
# 新北市
# 區
# 里
# 鄰
# 段
# 巷
# 弄
# 號
# 路(街)
# 樓之
# 簽名或蓋章 備註
# 新北市新店區中山里25鄰三溪園路
# 406
# Azz6.81278
# 875.11.19
# 467號二樓
#
# Fetching results/15560794818710564337/1/測試用連署書_手寫-0.json
# The document contains the following text:
# 號
# 編姓
# 新北市第11選舉區立法委員羅明才罷免案連署人名冊
# 名
# 國 民身 分 證 出生年月日
# 里 弄
# 籍
# 地
# 址
# 新北市
# 鄰
# 路(街) 簽名或蓋章 備註
# +1.2.21
# 號
# 統
# 編
# 仲
# 祭欣妤
# 吳淑芬
# 王雲
# 新北市新店區信義里15鄰
# 38.5.27
# F220951122
# 寶元路一段34巷2號三樓
# 段
# 巷
# 號
# 樓之
# A≥≥9947470
# L220623341
# 60.4.19 新北市新店區中山里6鄰
# 溪園路263號六樓
# 模欣好
# 吳淑芳
# 新北市新店區中山里1鄰
# 央北一路126號七樓
# 新北市第11選舉區立法委員羅明才罷免案連署人名冊
# 編姓
# 名
# 籍
# 地
# 址
# 編
# 國 民身 分 證 出生年月日
# 號 統
# 新北市
# 號
# 段
# 巷
# 里 弄
# 鄰
# 號
# 路(街)
# 樓之
# 簽名或蓋章 備註
# 江次郎
# 79.2.1
# F101965346
# 新北市新店區信義里7鄰寶慶街
# 6號+四樓之3
# 江次郎
# 張逢 五
# X120431215
# 40.5.27
# 陳冠銘
# 68.73
# A127494749
# 新北市新店區信義里16鄰
# 寶元路一段36號二樓
# 新北市新店區信義里14鄰中興路三段
# 229號二十三樓
# 鹽湯
# 新北市第11選舉區立法委員羅明才罷免案連署人名冊
# 編姓
# 號
# 姓國 統
# 名
# 籍
# 地
# 址
# 編
# 民身 分 證 出生年月日
# 號
# 新北市
# 段
# 巷
# 里
# 弄
# 鄰
# 號
# 路(街) 簽名或蓋章 備註
# 樓之
# 張秋香
# 2
# A222254809
# 70.4.7
# 新北市新店區張北里32鄰中興路
# 二段159號二樓
# 黄茹
# 新北市新店區張北里二鄰
# 79.2.1
# P220219868
# 胡文忠
# 中正路76巻11弄21號=横
# 黃菇紫
# F121195153
# 79.8.24
# 新北市新店區張北里21都徳正街24巻
# 29弄36號四樓
# 胡文忠
# 高美鈴
# 79.10.9
# 新北市新店張北里7
# 0221028446
# 中興路二段87號二樓
# 高美鈴
# 新北市第11選舉區立法委員羅明才罷免案連署人名冊
# 編姓
# 號
# 姓國 統
# 名
# 籍
# 地
# 址
# 民身 分 證 出生年月日
# 新北市
# 編
# 號
# 段
# 巷
# 弄
# 里 弄
# 鄰
# 路(街) 簽名或蓋章 備註
# 號
# 樓之
# 何沐恬
# 48.1.10
# A227049335
# 新北市新店區柴埕里5鄰安民街
# 67號十二樓
# 脂肪
# 何景瑄
# 43.8.x5
# F2Z3416826
# 新北市新店區柴埕里21鄰
# 光華街8巷17號二樓
# 游世来
# 57年1月13日 新北市新店區柴埕里6鄰安民街68號七樓
# F103935015
# 游如果
#
# Fetching results/15560794818710564337/2/測試用連署書_打字3人-0.json
# The document contains the following text:
# 新北市第11選舉區立法委員羅明才罷免案連署人名冊
# 編姓
# 國 民身
# 名
# 籍
# 地
# 址
# 號 統
# 分 證
# 編
# 出生年月日
# 新北市
# 里
# 號
# 段
# 陳台灣照明
# 48年6月4日
# 巷
# 新北市新店區香坡里41鄰安祥路85巷20號
# 弄
# 鄰
# 號
# 路(街)
# 樓之
# 簽名或蓋章 備註
# 陳台灣
# W135874109
# 照明
# 林莉純
# 52.3.14
# 新北市新店區香坡里32鄰安祥路14巷26號
# P254222910
# 林莉純
# 陳玉璽
# 新北市新店區香坡里3鄰安祥路2巷17號
# 83.9.25
# A176503711
# 陳玉豐
# 林寬諒
# U120703224
# 70年11月30日
# 新北市新店區中山里23鄰溪園路400號三樓
# 願望
# 2.2cm
# 25.4cm
# 新北市第11選舉區立法委員羅明才罷免案連署人名冊
# 編姓
# 號
# 姓國 統
# 名
# 籍
# 地
# 址
# 民身
# 分 證 出生年月日
# 編
# 號
# 新北市
# 里
# 鄰
# 路(街) 簽名或蓋章 備註
# 段
# 巷
# 弄
# 號
# 樓之
# 2.1cm
# 2.1cm
# 16.3cm
# 2.6cm
# 新北市第11選舉區立法委員羅明才罷免案連署人名冊
# 編 姓
# 名
# 戶
# 籍
# 地
# 址
# 號 統
# 編
# 國 民身 分 證 出生年月日
# 號
# 新北市
# 區
# 段
# 里
# 弄
# 鄰
# 號
# 路(街)
# 樓之
# 簽名或蓋章 備註
# X月
# 羅小明
# 88.8.8
# F123456789
# 新北市新店區小城里88鄰新烏路
# 一段88巷88弄88號三樓之9
# 羅小明
# ↑
# ↑
# 請勿 一筆一畫寫
# 填寫 勿接觸格線
# 請寫民國年
# 分隔用「.」
# 【按照身分證抄寫
# 舊地址寫新制
# 簽名或勿
# 蓋章 寫
# 個位數不需補「O」
# 88.8.8
# 「段」、「樓」的數字都要用國字
# 二段 三樓
# X88.08.08
# ▲建議拿出身分證對照,但不需留影本。
# A-人寫一張,方便後續造冊作業。
# 寫錯換一張,勿塗改。
# 【拔羅波|罷免羅明才】連署人聯繫資料暨個資使用同意書
# 本同意書說明【拔羅波|罷免羅明才】工作小組(以下簡稱本團隊)將如何處理蒐集、處理及利用
# 您的個人資料。當您簽署本同意書時,表示您已閱讀、瞭解並同意接受本同意書之所有內容。
# -
# 二、
# 三、
# 四、
# 本團隊將蒐集您於本同意書表格所填寫的各項個人資料(即姓名、出生年、聯絡電話、可聯
# 絡的行政區、里及路名)。
# 本團隊蒐集您個人資訊之目的限於:
# 1. 本團隊辦理【拔羅波︱罷免羅明才】之罷免連署造冊時如發現您所簽署的連署書有書寫
# 問題或其他可能影響連署效力問題時,用以聯繫您以確認、更正、修改或重新繕寫連署
# 文件。
# 2. 本團隊用以通知您【拔羅波|罷免羅明才】之罷免第三階段投票事宜。
# 本團隊利用您個人資料:
# 1. 期間為【拔羅波」罷免羅明才】之罷免案徵求連署期間至罷免案不成立、罷免案被否決
# 或罷免案通過時為止(為免疑義,即本罷免活動第二階段起至第三階段(如有)完成時
# 為止);
# 2.
# 地區為台灣及工作小組辦理罷免案作業所需的地點;
# 3. 對象為本團隊之成員;且
# 4. 方式為依照您填寫的個人資料以電話、簡訊、通訊軟體或其他適當方式聯繫您。
# 本團隊特此承諾將依照個人資料保護法之規定妥善蒐集、保管、處理及利用所蒐集之個人資
# 料。您可依照個人資料保護法第三條之規定行使您的權利,包括:向本團隊查詢;向本團隊
# 請求提供複本、補充或更正您的個人資料,或請求本團隊停止蒐集、處理、利用或刪除您的
# 個人資料。如您希望行使上述權利,請與本團隊聯繫:
# 拔羅波「罷免羅明才 https://www.facebook.com/baluobo1111
# 出生年
# 聯絡
# 姓名
# (民國)
# 電話
# 行政區
# 路名
# 里別
# (路+段)
# 我已閱讀並接受上述同意書內容。
# 簽署人:
# 簽署日期:

# %% [markdown]
# ### 步驟 1：處理批量處理的結果
#
# batch_process_documents() 方法的輸出結果會存儲在 Google Cloud Storage 中，通常是 JSON 格式的文件。您需要下載這些 JSON 文件，然後對每個文件進行資料萃取。

# %% [markdown]
# ### 步驟 2：下載批量處理的結果
# 使用 Google Cloud Storage 的 Python 客戶端庫下載處理結果：
#
# 下載結果的程式碼

# %%
from google.cloud import storage
import os
import json

def download_batch_results(bucket_name, output_prefix, local_output_dir):
    """下載批量處理的結果到本地"""
    # 初始化 GCS 客戶端
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)

    # 列出所有輸出文件
    blobs = bucket.list_blobs(prefix=output_prefix)
    os.makedirs(local_output_dir, exist_ok=True)

    downloaded_files = []
    for blob in blobs:
        # 只下載 JSON 文件
        if blob.name.endswith(".json"):
            local_file_path = os.path.join(local_output_dir, os.path.basename(blob.name))
            blob.download_to_filename(local_file_path)
            downloaded_files.append(local_file_path)
            print(f"下載文件: {blob.name} 到 {local_file_path}")

    return downloaded_files

# 使用範例
bucket_name = "bamien"
output_prefix = "results/15560794818710564337/"  # 批量處理的輸出目錄
local_output_dir = "./batch_results"  # 本地存儲目錄

downloaded_files = download_batch_results(bucket_name, output_prefix, local_output_dir)
# Out:
# 下載文件: results/15560794818710564337/0/測試用連署書-0.json 到 ./batch_results/測試用連署書-0.json
# 下載文件: results/15560794818710564337/1/測試用連署書_手寫-0.json 到 ./batch_results/測試用連署書_手寫-0.json
# 下載文件: results/15560794818710564337/2/測試用連署書_打字3人-0.json 到 ./batch_results/測試用連署書_打字3人-0.json

# %% [markdown]
# ### 步驟 3：解析批量處理的結果
# 每個 JSON 文件代表一個處理結果，您可以使用之前的 parse_document() 函式來解析這些結果。
#
# 解析 JSON 文件的程式碼

# %%
import os
import json
import re
import pandas as pd
from datetime import datetime
from openpyxl import Workbook


def parse_document_from_json(json_file_path, file_name):
    """從 JSON 文件中解析文檔內容，並判定頁碼"""
    with open(json_file_path, "r", encoding="utf-8") as f:
        document_data = json.load(f)

    # 獲取文檔的文字內容
    document_text = document_data.get("text", "")
    # 將文字內容按行分割
    lines = document_text.split("\n")

    # 初始化結果列表
    addresses = []
    birth_dates = []
    id_numbers = []
    names = []

    # 初始化頁碼
    current_page = 0
    noise_words = [
        "地址", "先生", "小姐", "姓名",
        "性別", "年齡", "民國", "新北市", "台北市", "中正區",
        "罷免案", "連署人", "名冊", "國統", "樓之","出生年","聯絡","電話","行政區","編姓"
    ]
    # 遍歷每一行
    for line_number, line_text in enumerate(lines, start=1):
        line_text = line_text.strip()
        if not line_text:
            continue  # 跳過空行

        # 判定是否是新的一頁
        if "罷免案連署人名冊" in line_text:
            current_page += 1  # 遇到標題時，頁碼加 1
            continue  # 跳過標題行

        # 初始化當前行的資料
        current_data = {
            "地址": None,
            "里": None,
            "鄰": None,
            "路/街": None,
            "出生年月日": None,
            "年齡": None,
            "身分證字號": None,
            "性別": None,
            "行號": line_number,
            "頁碼": current_page
        }

        # 提取名字

        # 提取名字
        if re.match(r"^[\u4e00-\u9fa5]{2,3}$", line_text) and line_text not in noise_words:
            names.append({
                "檔案名稱": file_name,
                "頁碼": current_page,
                "姓名": line_text
            })

        # 提取地址
        if "里" in line_text and "鄰" in line_text:
            current_data["地址"] = line_text
            current_data["里"] = extract_specific_field(line_text, r"([一-龥]{1,2})里")
            current_data["鄰"] = extract_specific_field(line_text, r"(\d{1,2})鄰")
            current_data["路/街"] = extract_specific_field(line_text, r"([一-龥]{1,3})(路|街)(?!鄰)")

        # 提取出生年月日
        birth_date = extract_birth_date(line_text)
        if birth_date:
            current_data["出生年月日"] = birth_date
            current_data["年齡"] = calculate_age(birth_date)

        # 提取身分證字號
        if re.search(r"[A-Z][0-9]+", line_text):
            current_data["身分證字號"] = line_text
            current_data["性別"] = determine_gender(line_text)

        # 如果該行有地址，存入地址列表
        if current_data["地址"]:
            addresses.append({
                "地址": current_data["地址"],
                "里": current_data["里"],
                "鄰": current_data["鄰"],
                "路/街": current_data["路/街"]
            })

        # 如果該行有出生年月日，存入出生年月日列表
        if current_data["出生年月日"]:
            birth_dates.append({
                "出生年月日": current_data["出生年月日"],
                "年齡": current_data["年齡"]
            })

        # 如果該行有身分證字號，存入身分證字號列表
        if current_data["身分證字號"]:
            id_numbers.append({
                "身分證字號前五碼": current_data["身分證字號"][:5],
                "性別": current_data["性別"]
            })

    return addresses, birth_dates, id_numbers, names


def extract_specific_field(text, pattern):
    """提取地址中的特定字段（如里、鄰、路/街）"""
    match = re.search(pattern, text)
    if match:
        result = match.group(0)
        return result.replace("鄰", "")  # 確保「鄰」字被移除
    return None

def extract_birth_date(text):
    """提取生日，支持多種格式並修正錯誤年份"""
    match = re.search(r"(\d{2,3}\.\d{1,2}\.\d{1,2})|民國(\d{2,3})年(\d{1,2})月(\d{1,2})日|(\d{2,3})年(\d{1,2})月(\d{1,2})日", text)
    if match:
        if match.group(1):  # 簡寫格式
            year, month, day = match.group(1).split(".")
            year = correct_year(year)
            return f"{year}.{month}.{day}"
        elif match.group(2):  # 民國完整格式
            year = correct_year(match.group(2))
            month = match.group(3)
            day = match.group(4)
            return f"{year}.{month}.{day}"
        elif match.group(5):  # 未標註民國的格式
            year = correct_year(match.group(5))
            month = match.group(6)
            day = match.group(7)
            return f"{year}.{month}.{day}"
    return None

def correct_year(year):
    """修正年份，確保符合規則"""
    year = int(year)
    if len(str(year)) == 3 and str(year)[0] != "1":
        year = int(str(year)[-2:])
    return year

def calculate_age(birth_date):
    """根據出生年月日計算年齡"""
    try:
        if re.match(r"^\d{2,3}\.\d{1,2}\.\d{1,2}$", birth_date):
            year, month, day = map(int, birth_date.split("."))
            year += 1911  # 民國轉西元
        else:
            return None

        birth_date = datetime(year, month, day)
        today = datetime.today()
        age = today.year - birth_date.year - ((today.month, today.day) < (birth_date.month, birth_date.day))
        return age
    except Exception as e:
        print(f"無法計算年齡: {e}")
        return None

def determine_gender(id_number):
    """根據身分證字號判斷性別"""
    try:
        match = re.search(r"[A-Z]([0-9])", id_number)
        if match:
            gender_digit = int(match.group(1))
            return "男性" if gender_digit == 1 else "女性"
        else:
            return None
    except Exception as e:
        print(f"無法判斷性別: {e}")
        return None

# 主程式
def main(json_files, output_excel_path):
    all_addresses = []
    all_birth_dates = []
    all_id_numbers = []
    all_names = []

    for json_file in json_files:
        file_name = os.path.basename(json_file)  # 提取檔案名稱
        print(f"處理文件: {json_file}")
        addresses, birth_dates, id_numbers, names = parse_document_from_json(json_file, file_name)
        all_addresses.extend(addresses)
        all_birth_dates.extend(birth_dates)
        all_id_numbers.extend(id_numbers)
        all_names.extend(names)

    # 將結果存入 DataFrame
    df_addresses = pd.DataFrame(all_addresses)
    df_birth_dates = pd.DataFrame(all_birth_dates)
    df_id_numbers = pd.DataFrame(all_id_numbers)
    df_names = pd.DataFrame(all_names)

    # 將 DataFrame 存入 Excel 的不同分頁
    with pd.ExcelWriter(output_excel_path, engine="openpyxl") as writer:
        df_addresses.to_excel(writer, sheet_name="地址", index=False)
        df_birth_dates.to_excel(writer, sheet_name="出生年月日", index=False)
        df_id_numbers.to_excel(writer, sheet_name="身分證字號", index=False)
        df_names.to_excel(writer, sheet_name="名字", index=False)

    print(f"結果已存入 {output_excel_path}")

# 執行資料萃取並存入 Excel
output_excel_path = "parsed_results.xlsx"
main(downloaded_files, output_excel_path)
# Out:
# 處理文件: ./batch_results/測試用連署書-0.json
# 處理文件: ./batch_results/測試用連署書_手寫-0.json
# 處理文件: ./batch_results/測試用連署書_打字3人-0.json
# 結果已存入 parsed_results.xlsx

# %% [markdown]
# ### 步驟 4：存成 CSV 文件
# 將合併後的 DataFrame 存成 CSV 文件：
#
# 存成 CSV 的程式碼
